# %%
from src.predict import load_model, predict

# Configurations
model_path = "fc_model_weights.pth"
test_image_folder = "data/test-data/"
image_name = "img_141.jpeg"  # image name

# %%
model = load_model(model_path)
fruit_name, confidence = predict(model, test_image_folder + image_name)

print(f"Image: {image_name}")
print(f"Predicted class: {fruit_name}")
print(f"Confidence: {(100*confidence):>0.1f}%")
